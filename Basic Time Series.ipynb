# %%
# https://medium.com/search?q=time%20series
# https://medium.com/search?q=classification
# https://towardsdatascience.com/basic-time-series-manipulation-with-pandas-4432afee64ea

# %%
import pandas as pd
from datetime import datetime
import numpy as np
date_rng = pd.date_range(start='1/1/2018', end='1/08/2018', freq='H')
date_rng
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00', '2018-01-01 05:00:00',
#                '2018-01-01 06:00:00', '2018-01-01 07:00:00',
#                '2018-01-01 08:00:00', '2018-01-01 09:00:00',
#                ...
#                '2018-01-07 15:00:00', '2018-01-07 16:00:00',
#                '2018-01-07 17:00:00', '2018-01-07 18:00:00',
#                '2018-01-07 19:00:00', '2018-01-07 20:00:00',
#                '2018-01-07 21:00:00', '2018-01-07 22:00:00',
#                '2018-01-07 23:00:00', '2018-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq='H')

# %%
type(date_rng[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = pd.DataFrame(date_rng, columns=['date'])
df['data'] = np.random.randint(0,100,size=(len(date_rng)))
df.head(15)
# Out:
#                   date  data
# 0  2018-01-01 00:00:00    30
# 1  2018-01-01 01:00:00    66
# 2  2018-01-01 02:00:00    91
# 3  2018-01-01 03:00:00    74
# 4  2018-01-01 04:00:00    14
# 5  2018-01-01 05:00:00    90
# 6  2018-01-01 06:00:00    47
# 7  2018-01-01 07:00:00    72
# 8  2018-01-01 08:00:00    61
# 9  2018-01-01 09:00:00    62
# 10 2018-01-01 10:00:00    93
# 11 2018-01-01 11:00:00    92
# 12 2018-01-01 12:00:00    97
# 13 2018-01-01 13:00:00    58
# 14 2018-01-01 14:00:00    81

# %%
# Convert the data frame index to a datetime index
df['datetime'] = pd.to_datetime(df['date'])
df = df.set_index('datetime')
df.drop(['date'], axis=1, inplace=True)
df.head()
# Out:
#                      data
# datetime
# 2018-01-01 00:00:00     4
# 2018-01-01 01:00:00    97
# 2018-01-01 02:00:00    19
# 2018-01-01 03:00:00    41
# 2018-01-01 04:00:00    33

# %%
string_date_rng = [str(x) for x in date_rng]
string_date_rng
# Out:
# ['2018-01-01 00:00:00',
#  '2018-01-01 01:00:00',
#  '2018-01-01 02:00:00',
#  '2018-01-01 03:00:00',
#  '2018-01-01 04:00:00',
#  '2018-01-01 05:00:00',
#  '2018-01-01 06:00:00',
#  '2018-01-01 07:00:00',
#  '2018-01-01 08:00:00',
#  '2018-01-01 09:00:00',
#  '2018-01-01 10:00:00',
#  '2018-01-01 11:00:00',
#  '2018-01-01 12:00:00',
#  '2018-01-01 13:00:00',
#  '2018-01-01 14:00:00',
#  '2018-01-01 15:00:00',
#  '2018-01-01 16:00:00',
#  '2018-01-01 17:00:00',
#  '2018-01-01 18:00:00',
#  '2018-01-01 19:00:00',
#  '2018-01-01 20:00:00',
#  '2018-01-01 21:00:00',
#  '2018-01-01 22:00:00',
#  '2018-01-01 23:00:00',
#  '2018-01-02 00:00:00',
#  '2018-01-02 01:00:00',
#  '2018-01-02 02:00:00',
#  '2018-01-02 03:00:00',
#  '2018-01-02 04:00:00',
#  '2018-01-02 05:00:00',
#  '2018-01-02 06:00:00',
#  '2018-01-02 07:00:00',
#  '2018-01-02 08:00:00',
#  '2018-01-02 09:00:00',
#  '2018-01-02 10:00:00',
#  '2018-01-02 11:00:00',
#  '2018-01-02 12:00:00',
#  '2018-01-02 13:00:00',
# ...

# %%
# convert the strings to timestamps
timestamp_date_rng = pd.to_datetime(string_date_rng, infer_datetime_format=True)
timestamp_date_rng
# Out:
# DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
#                '2018-01-01 02:00:00', '2018-01-01 03:00:00',
#                '2018-01-01 04:00:00', '2018-01-01 05:00:00',
#                '2018-01-01 06:00:00', '2018-01-01 07:00:00',
#                '2018-01-01 08:00:00', '2018-01-01 09:00:00',
#                ...
#                '2018-01-07 15:00:00', '2018-01-07 16:00:00',
#                '2018-01-07 17:00:00', '2018-01-07 18:00:00',
#                '2018-01-07 19:00:00', '2018-01-07 20:00:00',
#                '2018-01-07 21:00:00', '2018-01-07 22:00:00',
#                '2018-01-07 23:00:00', '2018-01-08 00:00:00'],
#               dtype='datetime64[ns]', length=169, freq=None)

# %%
# test str date time to timestamp date time 
string_date_rng_2 = ['June-01-2018', 'June-02-2018', 'June-03-2018']
timestamp_date_rng_2 = [datetime.strptime(x,'%B-%d-%Y') for x in string_date_rng_2]
timestamp_date_rng_2
# Out:
# [datetime.datetime(2018, 6, 1, 0, 0),
#  datetime.datetime(2018, 6, 2, 0, 0),
#  datetime.datetime(2018, 6, 3, 0, 0)]

# %%
df2 = pd.DataFrame(timestamp_date_rng_2, columns=['date'])
df2
# Out:
#         date
# 0 2018-06-01
# 1 2018-06-02
# 2 2018-06-03

# %%
df[df.index.day == 2]
# Out:
#                      data
# datetime
# 2018-01-02 00:00:00    38
# 2018-01-02 01:00:00    29
# 2018-01-02 02:00:00    19
# 2018-01-02 03:00:00    21
# 2018-01-02 04:00:00    68
# 2018-01-02 05:00:00    64
# 2018-01-02 06:00:00     3
# 2018-01-02 07:00:00    98
# 2018-01-02 08:00:00    84
# 2018-01-02 09:00:00    84
# 2018-01-02 10:00:00    50
# 2018-01-02 11:00:00    78
# 2018-01-02 12:00:00    91
# 2018-01-02 13:00:00    32
# 2018-01-02 14:00:00    72
# 2018-01-02 15:00:00    32
# 2018-01-02 16:00:00     0
# 2018-01-02 17:00:00    22
# 2018-01-02 18:00:00     6
# 2018-01-02 19:00:00    75
# 2018-01-02 20:00:00    49
# 2018-01-02 21:00:00    96
# 2018-01-02 22:00:00    49
# 2018-01-02 23:00:00    40
